# %% [markdown]
# ## Smartphone Market Analysis using Web Scraping - Flipkart Case Study
#
# ### Project Overview
#
# This project focuses on extracting **real-time smartphone data from Flipkart** using Python web scraping techniques (BeautifulSoup, Requests). The smartphone industry is highly competitive, with frequent product launches, fluctuating prices, and diverse customer preferences.
#
# The dataset includes product names, prices, discounts, ratings, and technical specifications, which are further cleaned and prepared for analysis.
#
# The ultimate goal is to visualize market trends in Power BI, providing insights into -
# - Price distribution across smartphone models
# - Discount patterns for different brands
# - Consumer rating behavior
# - Key feature comparisons (RAM, Battery, Display, Processor, Camera)
#
# This project simulates an end-to-end data analysis workflow — from raw web scraping to structured data analysis — showcasing practical skills in data collection, cleaning, transformation, and visualization.

# %% [markdown]
# ---

# %% [markdown]
# ### Phase 1 - Web Scraping
#
# Before beginning the data cleaning and analysis, we first need to collect the raw dataset.
# In this phase, we will scrape smartphone listings from **Flipkart** to capture essential details such as:
# - Brand & Model
# - Price & Discounts
# - Ratings
# - Key Specifications (RAM, ROM, Display, Battery, Processor, Camera, etc.)
#
# The scraped dataset will be stored in a structured format (CSV) and used in the next phase for transformation and analysis.

# %% [markdown]
# Importing Required Libraries

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time, random

# %% [markdown]
# Let's defines the scraping function, iterates through all pages, extracts product details and stores the results into a CSV file.

# %%
# Base setup
BASE_URL = "https://www.flipkart.com/search?q=smartphones&page={}"
HEADERS = {"User-Agent": "Mozilla/5.0"}
TOTAL_PAGES = 388
OUTPUT_FILE = "flipkart_smartphones.csv"

# Store all products
all_products = []

def scrape_page(page_num):
    try:
        url = BASE_URL.format(page_num)
        response = requests.get(url, headers=HEADERS)
        if response.status_code != 200:
            print(f"⚠️ Failed to fetch page {page_num}")
            return []
    except Exception as e:
        print(f"Error fetching {url}: {e}")
        return []
    
    soup = BeautifulSoup(response.text, "html.parser")
    data = []

    # Each product card
    product_cards = soup.find_all("div", {"class": "tUxRFH"})
    for card in product_cards:
        # Name
        name_tag = card.find("div", {"class": "KzDlHZ"})
        name = name_tag.text.strip() if name_tag else None

        # Price
        price_tag = card.find("div", {"class": "Nx9bqj _4b5DiR"})
        price = price_tag.text.strip().replace("₹", "").replace(",", "") if price_tag else None

        # Discount
        dis_tag = card.find("div", {"class": "UkUFwK"})
        discount = dis_tag.text.strip() if dis_tag else None

        # Rating
        rating_tag = card.find("div", {"class": "XQDdHH"})
        rating = rating_tag.text.strip() if rating_tag else None

        # Specs
        specs_container = card.find("div", {"class": "_6NESgJ"})
        if specs_container:
            specs_list = specs_container.find_all("li", {"class": "J+igdf"})
            specs = "; ".join([s.text.strip() for s in specs_list])
        else:
            specs = None

        if name:
            data.append({
                "Name": name,
                "Price": price,
                "Discount": discount,
                "Rating": rating,
                "Specs": specs
            })

    return data


# Main loop
for page in range(1, TOTAL_PAGES + 1):
    print(f"Scraping page {page}/{TOTAL_PAGES}...")
    products = scrape_page(page)
    all_products.extend(products)

    # Save progress every 20 pages
    if page % 20 == 0:
        pd.DataFrame(all_products).to_csv(OUTPUT_FILE, index=False)
        print(f"✅ Progress saved at page {page}")

    # Sleep to avoid blocking
    time.sleep(random.uniform(1, 3))

# Final save
df = pd.DataFrame(all_products)
df.to_csv(OUTPUT_FILE, index=False)
print(f"\n Done! Collected {len(df)} products into {OUTPUT_FILE}")
# Out:
# Scraping page 1/388...
# Scraping page 2/388...
# Scraping page 3/388...
# Scraping page 4/388...
# Scraping page 5/388...
# Scraping page 6/388...
# Scraping page 7/388...
# Scraping page 8/388...
# Scraping page 9/388...
# Scraping page 10/388...
# Scraping page 11/388...
# Scraping page 12/388...
# Scraping page 13/388...
# Scraping page 14/388...
# Scraping page 15/388...
# Scraping page 16/388...
# Scraping page 17/388...
# Scraping page 18/388...
# Scraping page 19/388...
# Scraping page 20/388...
# ✅ Progress saved at page 20
# Scraping page 21/388...
# Scraping page 22/388...
# Scraping page 23/388...
# Scraping page 24/388...
# Scraping page 25/388...
# Scraping page 26/388...
# Scraping page 27/388...
# Scraping page 28/388...
# Scraping page 29/388...
# Scraping page 30/388...
# Scraping page 31/388...
# Scraping page 32/388...
# Scraping page 33/388...
# Scraping page 34/388...
# Scraping page 35/388...
# Scraping page 36/388...
# Scraping page 37/388...
# Scraping page 38/388...
# Scraping page 39/388...
# Scraping page 40/388...
# ✅ Progress saved at page 40
# Scraping page 41/388...
# Scraping page 42/388...
# Scraping page 43/388...
# Scraping page 44/388...
# Scraping page 45/388...
# Scraping page 46/388...
# Scraping page 47/388...
# Scraping page 48/388...
# Scraping page 49/388...
# Scraping page 50/388...
# Scraping page 51/388...
# Scraping page 52/388...
# Scraping page 53/388...
# Scraping page 54/388...
# Scraping page 55/388...
# Scraping page 56/388...
# Scraping page 57/388...
# Scraping page 58/388...
# Scraping page 59/388...
# Scraping page 60/388...
# ✅ Progress saved at page 60
# Scraping page 61/388...
# Scraping page 62/388...
# Scraping page 63/388...
# Scraping page 64/388...
# Scraping page 65/388...
# Scraping page 66/388...
# Scraping page 67/388...
# Scraping page 68/388...
# Scraping page 69/388...
# Scraping page 70/388...
# Scraping page 71/388...
# Scraping page 72/388...
# Scraping page 73/388...
# Scraping page 74/388...
# Scraping page 75/388...
# Scraping page 76/388...
# Scraping page 77/388...
# Scraping page 78/388...
# Scraping page 79/388...
# Scraping page 80/388...
# ✅ Progress saved at page 80
# Scraping page 81/388...
# Scraping page 82/388...
# Scraping page 83/388...
# Scraping page 84/388...
# Scraping page 85/388...
# Scraping page 86/388...
# Scraping page 87/388...
# Scraping page 88/388...
# Scraping page 89/388...
# Scraping page 90/388...
# Scraping page 91/388...
# Scraping page 92/388...
# Scraping page 93/388...
# Scraping page 94/388...
# Scraping page 95/388...
# Scraping page 96/388...
# Scraping page 97/388...
# Scraping page 98/388...
# Scraping page 99/388...
# Scraping page 100/388...
# ✅ Progress saved at page 100
# Scraping page 101/388...
# Scraping page 102/388...
# Scraping page 103/388...
# Scraping page 104/388...
# Scraping page 105/388...
# Scraping page 106/388...
# Scraping page 107/388...
# Scraping page 108/388...
# Scraping page 109/388...
# Scraping page 110/388...
# Scraping page 111/388...
# Scraping page 112/388...
# Scraping page 113/388...
# Scraping page 114/388...
# Scraping page 115/388...
# Scraping page 116/388...
# Scraping page 117/388...
# Scraping page 118/388...
# Scraping page 119/388...
# Scraping page 120/388...
# ✅ Progress saved at page 120
# Scraping page 121/388...
# Scraping page 122/388...
# Scraping page 123/388...
# Scraping page 124/388...
# Scraping page 125/388...
# Scraping page 126/388...
# Scraping page 127/388...
# Scraping page 128/388...
# Scraping page 129/388...
# Scraping page 130/388...
# Scraping page 131/388...
# Scraping page 132/388...
# Scraping page 133/388...
# Scraping page 134/388...
# Scraping page 135/388...
# Scraping page 136/388...
# Scraping page 137/388...
# Scraping page 138/388...
# Scraping page 139/388...
# Scraping page 140/388...
# ✅ Progress saved at page 140
# Scraping page 141/388...
# Scraping page 142/388...
# Scraping page 143/388...
# Scraping page 144/388...
# Scraping page 145/388...
# Scraping page 146/388...
# Scraping page 147/388...
# Scraping page 148/388...
# Scraping page 149/388...
# Scraping page 150/388...
# Scraping page 151/388...
# Scraping page 152/388...
# Scraping page 153/388...
# Scraping page 154/388...
# Scraping page 155/388...
# Scraping page 156/388...
# Scraping page 157/388...
# Scraping page 158/388...
# Scraping page 159/388...
# Scraping page 160/388...
# ✅ Progress saved at page 160
# Scraping page 161/388...
# Scraping page 162/388...
# Scraping page 163/388...
# Scraping page 164/388...
# Scraping page 165/388...
# Scraping page 166/388...
# Scraping page 167/388...
# Scraping page 168/388...
# Scraping page 169/388...
# Scraping page 170/388...
# Scraping page 171/388...
# Scraping page 172/388...
# Scraping page 173/388...
# Scraping page 174/388...
# Scraping page 175/388...
# Scraping page 176/388...
# Scraping page 177/388...
# Scraping page 178/388...
# Scraping page 179/388...
# Scraping page 180/388...
# ✅ Progress saved at page 180
# Scraping page 181/388...
# Scraping page 182/388...
# Scraping page 183/388...
# Scraping page 184/388...
# Scraping page 185/388...
# Scraping page 186/388...
# Scraping page 187/388...
# Scraping page 188/388...
# Scraping page 189/388...
# Scraping page 190/388...
# Scraping page 191/388...
# Scraping page 192/388...
# Scraping page 193/388...
# Scraping page 194/388...
# Scraping page 195/388...
# Scraping page 196/388...
# Scraping page 197/388...
# Scraping page 198/388...
# Scraping page 199/388...
# Scraping page 200/388...
# ✅ Progress saved at page 200
# Scraping page 201/388...
# Scraping page 202/388...
# Scraping page 203/388...
# Scraping page 204/388...
# Scraping page 205/388...
# Scraping page 206/388...
# Scraping page 207/388...
# Scraping page 208/388...
# Scraping page 209/388...
# Scraping page 210/388...
# Scraping page 211/388...
# Scraping page 212/388...
# Scraping page 213/388...
# Scraping page 214/388...
# Scraping page 215/388...
# Scraping page 216/388...
# Scraping page 217/388...
# Scraping page 218/388...
# Scraping page 219/388...
# Scraping page 220/388...
# ✅ Progress saved at page 220
# Scraping page 221/388...
# Scraping page 222/388...
# Scraping page 223/388...
# Scraping page 224/388...
# Scraping page 225/388...
# Scraping page 226/388...
# Scraping page 227/388...
# Scraping page 228/388...
# Scraping page 229/388...
# Scraping page 230/388...
# Scraping page 231/388...
# Scraping page 232/388...
# Scraping page 233/388...
# Scraping page 234/388...
# Scraping page 235/388...
# Scraping page 236/388...
# Scraping page 237/388...
# Scraping page 238/388...
# Scraping page 239/388...
# Scraping page 240/388...
# ✅ Progress saved at page 240
# Scraping page 241/388...
# Scraping page 242/388...
# Scraping page 243/388...
# Scraping page 244/388...
# Scraping page 245/388...
# Scraping page 246/388...
# Scraping page 247/388...
# Scraping page 248/388...
# Scraping page 249/388...
# Scraping page 250/388...
# Scraping page 251/388...
# Scraping page 252/388...
# Scraping page 253/388...
# Scraping page 254/388...
# Scraping page 255/388...
# Scraping page 256/388...
# Scraping page 257/388...
# Scraping page 258/388...
# Scraping page 259/388...
# Scraping page 260/388...
# ✅ Progress saved at page 260
# Scraping page 261/388...
# Scraping page 262/388...
# Scraping page 263/388...
# Scraping page 264/388...
# Scraping page 265/388...
# Scraping page 266/388...
# Scraping page 267/388...
# Scraping page 268/388...
# Scraping page 269/388...
# Scraping page 270/388...
# Scraping page 271/388...
# Scraping page 272/388...
# Scraping page 273/388...
# Scraping page 274/388...
# Scraping page 275/388...
# Scraping page 276/388...
# Scraping page 277/388...
# Scraping page 278/388...
# Scraping page 279/388...
# Scraping page 280/388...
# ✅ Progress saved at page 280
# Scraping page 281/388...
# Scraping page 282/388...
# Scraping page 283/388...
# Scraping page 284/388...
# Scraping page 285/388...
# Scraping page 286/388...
# Scraping page 287/388...
# Scraping page 288/388...
# Scraping page 289/388...
# Scraping page 290/388...
# Scraping page 291/388...
# Scraping page 292/388...
# Scraping page 293/388...
# Scraping page 294/388...
# Scraping page 295/388...
# Scraping page 296/388...
# Scraping page 297/388...
# Scraping page 298/388...
# Scraping page 299/388...
# Scraping page 300/388...
# ✅ Progress saved at page 300
# Scraping page 301/388...
# Scraping page 302/388...
# Scraping page 303/388...
# Scraping page 304/388...
# Scraping page 305/388...
# Scraping page 306/388...
# Scraping page 307/388...
# Scraping page 308/388...
# Scraping page 309/388...
# Scraping page 310/388...
# Scraping page 311/388...
# Scraping page 312/388...
# Scraping page 313/388...
# Scraping page 314/388...
# Scraping page 315/388...
# Scraping page 316/388...
# Scraping page 317/388...
# Scraping page 318/388...
# Scraping page 319/388...
# Scraping page 320/388...
# ✅ Progress saved at page 320
# Scraping page 321/388...
# Scraping page 322/388...
# Scraping page 323/388...
# Scraping page 324/388...
# Scraping page 325/388...
# Scraping page 326/388...
# Scraping page 327/388...
# Scraping page 328/388...
# Scraping page 329/388...
# Scraping page 330/388...
# Scraping page 331/388...
# Scraping page 332/388...
# Scraping page 333/388...
# Scraping page 334/388...
# Scraping page 335/388...
# Scraping page 336/388...
# Scraping page 337/388...
# Scraping page 338/388...
# Scraping page 339/388...
# Scraping page 340/388...
# ✅ Progress saved at page 340
# Scraping page 341/388...
# Scraping page 342/388...
# Scraping page 343/388...
# Scraping page 344/388...
# Scraping page 345/388...
# Scraping page 346/388...
# Scraping page 347/388...
# Scraping page 348/388...
# Scraping page 349/388...
# Scraping page 350/388...
# Scraping page 351/388...
# Scraping page 352/388...
# Scraping page 353/388...
# Scraping page 354/388...
# Scraping page 355/388...
# Scraping page 356/388...
# Scraping page 357/388...
# Scraping page 358/388...
# Scraping page 359/388...
# Scraping page 360/388...
# ✅ Progress saved at page 360
# Scraping page 361/388...
# Scraping page 362/388...
# Scraping page 363/388...
# Scraping page 364/388...
# Scraping page 365/388...
# Scraping page 366/388...
# Scraping page 367/388...
# Scraping page 368/388...
# Scraping page 369/388...
# Scraping page 370/388...
# Scraping page 371/388...
# Scraping page 372/388...
# Scraping page 373/388...
# Scraping page 374/388...
# Scraping page 375/388...
# Scraping page 376/388...
# Scraping page 377/388...
# Scraping page 378/388...
# Scraping page 379/388...
# Scraping page 380/388...
# ✅ Progress saved at page 380
# Scraping page 381/388...
# Scraping page 382/388...
# Scraping page 383/388...
# Scraping page 384/388...
# Scraping page 385/388...
# Scraping page 386/388...
# Scraping page 387/388...
# Scraping page 388/388...
#
#  Done! Collected 984 products into flipkart_smartphones.csv

# %% [markdown]
# ---

# %% [markdown]
# ### Phase 2 - Data Preparation & Transformation
#
# The web scraping phase is now complete, and we have successfully collected raw smartphone data from Flipkart.
# The dataset has been saved to **`flipkart_smartphones`**, which will serve as the foundation for further analysis.
#
# In the upcoming **Data Preparation & Transformation** notebook, we will:
# - Assess and improve data quality
# - Handle missing values and duplicates
# - Standardize specifications (RAM, ROM, Display, Battery, etc.)
# - Prepare the dataset for Exploratory Data Analysis (EDA)
#
# *Proceeding to the transformation stage ensures that the data is structured, reliable, and ready to generate actionable business insights.*

# %% [markdown]
# ---
# ---
